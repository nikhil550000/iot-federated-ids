# %%
# Install dependencies
# !pip install torch flwr[simulation] pandas

# %%
# Import modules using absolute paths
import sys
sys.path.append("/content/drive/MyDrive/iot_federated_ids/src")

# Import modules using absolute path within the package
from src.federated.client import PyTorchClient
from src.federated.server import start_server
from src.config import Config
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-13d196953efd> in <cell line: 0>()
#       4
#       5 # Import modules using absolute path within the package
# ----> 6 from src.federated.client import PyTorchClient
#       7 from src.federated.server import start_server
#       8 from src.config import Config
#
# ModuleNotFoundError: No module named 'src'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# Import modules
import flwr as fl
from src.federated.client import PyTorchClient
from src.federated.server import start_server
from src.config import Config

# %%
# Define client function
def client_fn(cid: str):
    return PyTorchClient(int(cid) + 1)  # Client IDs start at 1

# %%
# Start federated training
fl.simulation.start_simulation(
    client_fn=client_fn,
    num_clients=Config.num_clients,
    config=fl.server.ServerConfig(num_rounds=Config.num_rounds),
    strategy=fl.server.strategy.FedAvg(),
)

# %%
# Save the global model
import torch
from federated.utils import IDSModel
from config import Config

model = IDSModel()
# Load parameters if needed (optional)
torch.save(model.state_dict(), Config.model_save_path)
